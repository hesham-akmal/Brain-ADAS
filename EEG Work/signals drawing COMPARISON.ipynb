# %%
from signals_visualization3 import *
from signals_classification import *
# %matplotlib inline

# %%
upload_and_draw("Wagih5", False)

# %%
upload_and_draw("Wagih5", True)

# %%
upload_and_draw("Wagih2", False)
# Out:
# Subject_1.csv

# %%
upload_and_draw("Wagih2", True)
# Out:
# Subject_1.csv

# %%
upload_and_draw("Tair4", False)
# Out:
# Subject_1.csv

# %%
upload_and_draw("Tair4", True)
# Out:
# Subject_1.csv

# %%
upload_and_draw("Tair2", False)
# Out:
# Subject_1.csv
# Subject_2.csv

# %%
upload_and_draw("Tair2", True)
# Out:
# Subject_1.csv
# Subject_2.csv
