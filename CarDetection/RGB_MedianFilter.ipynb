# %%
import numpy as np , math
from skimage import io
# %matplotlib inline

# %%
def RGB_MedianFilter(img , mask_size):
    R,C = img.shape[0] , img.shape[1]
    R_img = img[:,:,0]
    G_img = img[:,:,1]
    B_img = img[:,:,2]
    t = mask_size//2
    u = t+1
    
    fltrd_img = np.zeros(img.shape, dtype = img.dtype)
    fltrd_img_R = fltrd_img[:,:,0]
    fltrd_img_G = fltrd_img[:,:,1]
    fltrd_img_B = fltrd_img[:,:,2]
    
    for i in range(t,R-t):
        for j in range(t,C-t): 
            R_window = R_img[i-t:i+u , j-t:j+u]
            fltrd_img_R[i,j] = np.median(R_window)
            
            G_window = G_img[i-t:i+u , j-t:j+u]
            fltrd_img_G[i,j] = np.median(G_window)
            
            B_window = B_img[i-t:i+u , j-t:j+u]
            fltrd_img_B[i,j] = np.median(B_window)
            
    fltrd_img[:,:,0] = fltrd_img_R
    fltrd_img[:,:,1] = fltrd_img_G
    fltrd_img[:,:,2] = fltrd_img_B
    
            
    return fltrd_img

# %%
img = io.imread('test0.jpg')
io.imshow(img)
print(img.dtype)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-a1a1f42fb5f7> in <module>
# ----> 1 img = io.imread('test0.jpg')
#       2 io.imshow(img)
#       3 print(img.dtype)
#
# ~/ENVp3/lib/python3.5/site-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, flatten, **plugin_args)
#      60
#      61     with file_or_url_context(fname) as fname:
# ---> 62         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      63
#      64     if not hasattr(img, 'ndim'):
#
# ~/ENVp3/lib/python3.5/site-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     212                                (plugin, kind))
#     213
# --> 214     return func(*args, **kwargs)
#     215
#     216
#
# ~/ENVp3/lib/python3.5/site-packages/skimage/io/_plugins/pil_plugin.py in imread(fname, dtype, img_num, **kwargs)
#      33     """
# ...

# %%
img2 = RGB_MedianFilter(img,7)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-2203471ba607> in <module>
# ----> 1 img2 = RGB_MedianFilter(img,7)
#
# NameError: name 'img' is not defined

# %%
io.imshow(img2)
print(img2.dtype)
# Out:
# uint8
